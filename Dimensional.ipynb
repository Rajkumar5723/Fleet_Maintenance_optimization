# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
data_path = r"C:\Users\lenovo\Downloads\Real_Time_Features_Dimensionality_Reduction_Dataset.csv"
data = pd.read_csv(data_path)

# %%
X = data.drop(columns=["Vehicle_ID", "Target"])

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %%
explained_variance = pca.explained_variance_ratio_
print("Explained Variance Ratio:", explained_variance)

plt.figure(figsize=(8, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=data['Target'], cmap='viridis', alpha=0.6)
plt.colorbar(label='Target')
plt.title('PCA: First Two Principal Components')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.grid(True)
plt.show()
# Out:
# Explained Variance Ratio: [0.15069431 0.14661572]

# %%
pca_data = pd.DataFrame(X_pca, columns=["PC1", "PC2"])
pca_data["Target"] = data["Target"]

pca_data_path = "PCA_Reduced_Real_Time_Features_Dataset.csv"
pca_data.to_csv(pca_data_path, index=False)

print(f"PCA Reduced dataset saved to {pca_data_path}")
# Out:
# PCA Reduced dataset saved to PCA_Reduced_Real_Time_Features_Dataset.csv
